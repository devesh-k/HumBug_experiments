# %%
# %%html
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>
# CUDA_LAUNCH_BLOCKING=1
# Out:
# <style type='text/css'>
# .CodeMirror{
# font-size: 14px;
# </style>
# CUDA_LAUNCH_BLOCKING=1

# %%
# I had to find the right version of pytorch with the widget here https://pytorch.org/
# I *think* this will work with AWS
#!pip3 install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
# other dependencies
#!pip install timm ipywidgets

# %%
## nnAudio
#!pip install git+https://github.com/KinWaiCheuk/nnAudio.git#subdirectory=Installation

# %% [markdown]
# ### 1 Import the kitchen sink

# %%
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8

# %%
# humbug main imports
import os
import pandas as pd
import sys
sys.path.insert(0, os.path.abspath('../../src'))
import config ,config_pytorch
from evaluate import get_results
import numpy as np

# Troubleshooting and visualisation
import IPython.display as ipd

# %%
# humbug lib imports
from sklearn.metrics import accuracy_score
#from PyTorch import config_pytorch
from datetime import datetime
import math
import pickle

from torch.utils.data import TensorDataset, DataLoader
import torch.nn.functional as F
import torch.nn as nn
import torch
import torch.optim as optim
import numpy as np
from sklearn.metrics import accuracy_score
from datetime import datetime
import os
import time

import matplotlib
import matplotlib.pyplot as plt
import sklearn
from sklearn.metrics import confusion_matrix, classification_report,f1_score,accuracy_score
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve
from sklearn.metrics import average_precision_score
import sys

from tqdm.notebook import tqdm

# %%
# additional pytorch tools
import random
import torchaudio
import torchaudio.transforms as T
import torchvision.transforms as VT
from torch.cuda.amp import autocast, GradScaler
from timm.scheduler.cosine_lr import CosineLRScheduler
import timm
import timm.optim
from timm.loss import BinaryCrossEntropy
from timm.utils import NativeScaler
from timm.models import model_parameters
from glob import glob

# %%
## nnAudio
from nnAudio import features
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset, DataLoader

# %%
#similarity learning
import numpy as np
import os
import tqdm
from torch.utils.data import Dataset, Subset
from torchvision import datasets, transforms
from typing import Callable
import torchvision
from torch import nn
from typing import Dict, Union, Optional, List
import os
from torch_audiomentations import Compose, Gain, PolarityInversion,AddColoredNoise,ApplyImpulseResponse,PeakNormalization,TimeInversion
import torch

# %% [markdown]
# ### Run all these function definition cells
# These have been extracted from the lib folder and are here to make them more easily editable.  Most of the action happens in *get_feat_torch*, which does feature extraction and *train_model*

# %%
#Global Training variables 
DEBUG = False
num_epochs = 200

# %%
#torch.autograd.set_detect_anomaly(True)

# %%
def get_offsets_df(df, short_audio=False):
    audio_offsets = []
    min_length = config.win_size*config.NFFT/(((1/config.n_hop)*config.NFFT)*config.rate)
    step_frac = config.step_size/config.win_size
    for _,row in df.iterrows():
        if row['length'] > min_length:
            step_size = step_frac*min_length
            audio_offsets.append({'id':row['id'], 'offset':0, 'length': row['length'],'specie_ind': row['specie_ind']})
            for i in range(1, int((row['length']-min_length)//step_size)):
                audio_offsets.append({'id': row['id'], 'offset':int(min_length+(i*step_size)*config.rate), 'length': row['length'],'specie_ind': row['specie_ind']})
        elif short_audio:
            audio_offsets.append({'id':row['id'], 'offset':0,'length': row['length'],'specie_ind': row['specie_ind']})
    return pd.DataFrame(audio_offsets)

# %%
def concat_df(df_offset, indices):
    list_df_ind = []
    #print("len of indices = " + str(len(indices)))
    for ind in indices :
        df_name = "df_"+ str(ind)
        df_name = df_offset[df_offset['specie_ind'] == ind]
        list_df_ind.append(df_name)
    df_offset_trimmed = pd.concat(list_df_ind)
    return(df_offset_trimmed)

# %%
#check the min length based on config params
min_length = (config.win_size * config.n_hop) / config.rate
min_length
# Out:
# 1.92

# %% [markdown]
# ### 3 The Data

# %% [markdown]
# ### Read CSV and get train/test groups

# %%
classes = ['an arabiensis','culex pipiens complex', 'ae aegypti','an funestus ss','an squamosus',
               'an coustani','ma uniformis','ma africanus']

# %%
#if DEBUG:
#df = pd.read_csv(config.data_df_msc_test)
#else:
df = pd.read_csv(config.data_df)

#df = df.loc[df['Grade'].notnull()]
df = df.loc[df['species'].notnull()]
df
# Out:
#         id     length                             name  sample_rate  \
# 1       53   0.463456  CDC_Ae-aegypti_labelled_800.wav         8000
# 2       57   0.170249  CDC_Ae-aegypti_labelled_800.wav         8000
# 3       61   0.104041  CDC_Ae-aegypti_labelled_800.wav         8000
# 4       69   0.274290  CDC_Ae-aegypti_labelled_800.wav         8000
# 5       56   0.420894  CDC_Ae-aegypti_labelled_800.wav         8000
# ...    ...        ...                              ...          ...
# 8999  3562   6.083093                    #988-1001.wav        44100
# 9000  3556   6.719908                    #988-1001.wav        44100
# 9009  3553   6.128580                    #988-1001.wav        44100
# 9011  3561  11.614280                    #988-1001.wav        44100
# 9012  3552   2.920249                    #988-1001.wav        44100
#
#      record_datetime sound_type       species  gender  fed plurality  age  \
# 1      8/9/2016 8:00   mosquito    ae aegypti     NaN  NaN    Single  NaN
# 2      8/9/2016 8:00   mosquito    ae aegypti     NaN  NaN    Single  NaN
# 3      8/9/2016 8:00   mosquito    ae aegypti     NaN  NaN    Single  NaN
# 4      8/9/2016 8:00   mosquito    ae aegypti     NaN  NaN    Single  NaN
# 5      8/9/2016 8:00   mosquito    ae aegypti     NaN  NaN    Plural  NaN
# ...              ...        ...           ...     ...  ...       ...  ...
# 8999  1/7/2018 12:00   mosquito  an harrisoni  Female    t    Single  NaN
# 9000  1/7/2018 12:00   mosquito  an maculatus  Female    t    Single  NaN
# 9009  1/7/2018 12:00   mosquito  an maculatus  Female    t    Single  NaN
# 9011  1/7/2018 12:00   mosquito  an harrisoni  Female    t    Single  NaN
# 9012  1/7/2018 12:00   mosquito  an harrisoni  Female    t    Single  NaN
#
#      method mic_type    device_type   country          district  \
# 1       NaN    phone  Alcatel 4009X       USA           Georgia
# 2       NaN    phone  Alcatel 4009X       USA           Georgia
# 3       NaN    phone  Alcatel 4009X       USA           Georgia
# 4       NaN    phone  Alcatel 4009X       USA           Georgia
# 5       NaN    phone  Alcatel 4009X       USA           Georgia
# ...     ...      ...            ...       ...               ...
# 8999    ABN  telinga        olympus  Thailand  Sai Yok District
# 9000    ABN  telinga        olympus  Thailand  Sai Yok District
# 9009    ABN  telinga        olympus  Thailand  Sai Yok District
# 9011    ABN  telinga        olympus  Thailand  Sai Yok District
# 9012    ABN  telinga        olympus  Thailand  Sai Yok District
#
#                    province                            place location_type
# 1                   Atlanta     CDC insect cultures, Atlanta       culture
# 2                   Atlanta     CDC insect cultures, Atlanta       culture
# 3                   Atlanta     CDC insect cultures, Atlanta       culture
# 4                   Atlanta     CDC insect cultures, Atlanta       culture
# 5                   Atlanta     CDC insect cultures, Atlanta       culture
# ...                     ...                              ...           ...
# 8999  Kanchanaburi Province  field site near Pu Teuy Village           cup
# 9000  Kanchanaburi Province  field site near Pu Teuy Village           cup
# 9009  Kanchanaburi Province  field site near Pu Teuy Village           cup
# 9011  Kanchanaburi Province  field site near Pu Teuy Village           cup
# 9012  Kanchanaburi Province  field site near Pu Teuy Village           cup
#
# [6008 rows x 19 columns]

# %%
# adding a colum for specie encoding
df['specie_ind'] = "NULL_VAL"

# %%
ind = 0
for specie in classes:
    print("specie = " + str(specie) + "and its index = " + str(ind) )
    row_indexes=df[df['species']==specie].index 
    df.loc[row_indexes,'specie_ind']= ind
    ind+=1

    
# other_df_ind = df[df['specie_ind'] == "NULL_VAL"].index
# df.loc[other_df_ind,'specie_ind']= other_ind
# Out:
# specie = an arabiensisand its index = 0
# specie = culex pipiens complexand its index = 1
# specie = ae aegyptiand its index = 2
# specie = an funestus ssand its index = 3
# specie = an squamosusand its index = 4
# specie = an coustaniand its index = 5
# specie = ma uniformisand its index = 6
# specie = ma africanusand its index = 7

# %%
USE_SHORT_AUDIO = True

# %%
df.drop(df[df['specie_ind'] == "NULL_VAL"].index, inplace=True)
#other_df_ind = df[df['specie_ind'] == "NULL_VAL"].index
#df.loc[other_df_ind,'specie_ind']= other_ind

# %%
idx_multiclass = np.logical_and(df['country'] == 'Tanzania', df['location_type'] == 'cup')
df_all = df[idx_multiclass]

# %%
df_all.reset_index(inplace=True)

# %%
df_all
# Out:
#       index      id  length                name  sample_rate record_datetime  \
# 0      1879  221103    2.56   IFA_17_24_664.wav        44100  30-01-20 00:00
# 1      1880  221111    2.56   IFA_17_25_665.wav        44100  30-01-20 00:00
# 2      1881  221110    2.56   IFA_17_25_665.wav        44100  30-01-20 00:00
# 3      1882  221149    2.56   IFA_17_26_666.wav        44100  30-01-20 00:00
# 4      1883  221150    2.56   IFA_17_26_666.wav        44100  30-01-20 00:00
# ...     ...     ...     ...                 ...          ...             ...
# 2283   4546  222615   30.72  IFA_86_39_3439.wav        44100  23-08-20 00:00
# 2284   4547  222585   25.60  IFA_86_40_3440.wav        44100  23-08-20 00:00
# 2285   4548  222586   40.90  IFA_87_10_3450.wav        44100  23-08-20 00:00
# 2286   4549  222596   40.90  IFA_87_11_3451.wav        44100  23-08-20 00:00
# 2287   4550  222614   38.40  IFA_87_12_3452.wav        44100  23-08-20 00:00
#
#      sound_type         species  gender fed  ... age  method mic_type  \
# 0      mosquito    ma africanus  Female   f  ... NaN     HBN  telinga
# 1      mosquito    ma africanus  Female   f  ... NaN     HBN  telinga
# 2      mosquito    ma africanus  Female   f  ... NaN     HBN  telinga
# 3      mosquito   an arabiensis  Female   f  ... NaN     HBN  telinga
# 4      mosquito   an arabiensis  Female   f  ... NaN     HBN  telinga
# ...         ...             ...     ...  ..  ...  ..     ...      ...
# 2283   mosquito  an funestus ss  Female   f  ... NaN      LT  telinga
# 2284   mosquito  an funestus ss  Female   f  ... NaN      LT  telinga
# 2285   mosquito  an funestus ss  Female   f  ... NaN      LT  telinga
# 2286   mosquito  an funestus ss  Female   f  ... NaN      LT  telinga
# 2287   mosquito  an funestus ss  Female   f  ... NaN      LT  telinga
#
#      device_type   country            district  province    place  \
# 0         tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 1         tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 2         tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 3         tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 4         tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# ...          ...       ...                 ...       ...      ...
# 2283      tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 2284      tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 2285      tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 2286      tascam  Tanzania  Kilombero District  Morogoro  Ifakara
# 2287      tascam  Tanzania  Kilombero District  Morogoro  Ifakara
#
#      location_type specie_ind
# 0              cup          7
# 1              cup          7
# 2              cup          7
# 3              cup          0
# 4              cup          0
# ...            ...        ...
# 2283           cup          3
# 2284           cup          3
# 2285           cup          3
# 2286           cup          3
# 2287           cup          3
#
# [2288 rows x 21 columns]

# %% [markdown]
# ### Train-test Split

# %%
np.random.seed(42)
msk_test = np.random.rand(len(df_all)) < 0.2
df_test = df_all[msk_test]
df_train_temp  = df_all[~msk_test]

# %%
np.random.seed(42)
msk_train = np.random.rand(len(df_train_temp)) < 0.2
df_val = df_train_temp[msk_train]
df_train  = df_train_temp[~msk_train]

# %%
df_train.head()
# Out:
#     index      id  length               name  sample_rate record_datetime  \
# 0    1879  221103    2.56  IFA_17_24_664.wav        44100  30-01-20 00:00
# 1    1880  221111    2.56  IFA_17_25_665.wav        44100  30-01-20 00:00
# 2    1881  221110    2.56  IFA_17_25_665.wav        44100  30-01-20 00:00
# 3    1882  221149    2.56  IFA_17_26_666.wav        44100  30-01-20 00:00
# 11   1890  221144    2.56  IFA_17_28_668.wav        44100  30-01-20 00:00
#
#    sound_type                species  gender fed  ... age  method mic_type  \
# 0    mosquito           ma africanus  Female   f  ... NaN     HBN  telinga
# 1    mosquito           ma africanus  Female   f  ... NaN     HBN  telinga
# 2    mosquito           ma africanus  Female   f  ... NaN     HBN  telinga
# 3    mosquito          an arabiensis  Female   f  ... NaN     HBN  telinga
# 11   mosquito  culex pipiens complex  Female   f  ... NaN     HBN  telinga
#
#    device_type   country            district  province    place location_type  \
# 0       tascam  Tanzania  Kilombero District  Morogoro  Ifakara           cup
# 1       tascam  Tanzania  Kilombero District  Morogoro  Ifakara           cup
# 2       tascam  Tanzania  Kilombero District  Morogoro  Ifakara           cup
# 3       tascam  Tanzania  Kilombero District  Morogoro  Ifakara           cup
# 11      tascam  Tanzania  Kilombero District  Morogoro  Ifakara           cup
#
#    specie_ind
# 0           7
# 1           7
# 2           7
# 3           0
# 11          1
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Let's verify for data leakage by performing an inner-join on id

# %%
pd.merge(df_test,df_train, on = 'id', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [index_x, id, length_x, name_x, sample_rate_x, record_datetime_x, sound_type_x, species_x, gender_x, fed_x, plurality_x, age_x, method_x, mic_type_x, device_type_x, country_x, district_x, province_x, place_x, location_type_x, specie_ind_x, index_y, length_y, name_y, sample_rate_y, record_datetime_y, sound_type_y, species_y, gender_y, fed_y, plurality_y, age_y, method_y, mic_type_y, device_type_y, country_y, district_y, province_y, place_y, location_type_y, specie_ind_y]
# Index: []
#
# [0 rows x 41 columns]

# %%
pd.merge(df_test,df_val, on = 'id', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [index_x, id, length_x, name_x, sample_rate_x, record_datetime_x, sound_type_x, species_x, gender_x, fed_x, plurality_x, age_x, method_x, mic_type_x, device_type_x, country_x, district_x, province_x, place_x, location_type_x, specie_ind_x, index_y, length_y, name_y, sample_rate_y, record_datetime_y, sound_type_y, species_y, gender_y, fed_y, plurality_y, age_y, method_y, mic_type_y, device_type_y, country_y, district_y, province_y, place_y, location_type_y, specie_ind_y]
# Index: []
#
# [0 rows x 41 columns]

# %%
pd.merge(df_train,df_val, on = 'id', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [index_x, id, length_x, name_x, sample_rate_x, record_datetime_x, sound_type_x, species_x, gender_x, fed_x, plurality_x, age_x, method_x, mic_type_x, device_type_x, country_x, district_x, province_x, place_x, location_type_x, specie_ind_x, index_y, length_y, name_y, sample_rate_y, record_datetime_y, sound_type_y, species_y, gender_y, fed_y, plurality_y, age_y, method_y, mic_type_y, device_type_y, country_y, district_y, province_y, place_y, location_type_y, specie_ind_y]
# Index: []
#
# [0 rows x 41 columns]

# %% [markdown]
# ### Next, we perform "offsets", spliting each(long) recording into multiple 1.92 secs chunk.

# %%
df_train_offset = get_offsets_df(df_train, short_audio=USE_SHORT_AUDIO)
df_test_offset = get_offsets_df(df_test, short_audio=USE_SHORT_AUDIO)
df_val_offset = get_offsets_df(df_val, short_audio=USE_SHORT_AUDIO)

# %%
print("length of train offset = " +str(len(df_train_offset)))
print("length of test offset = " +str(len(df_test_offset)))
print("length of val offset = " +str(len(df_val_offset)))
# Out:
# length of train offset = 32239
# length of test offset = 10087
# length of val offset = 8692

# %%
#df_temp.reset_index(inplace = True)
df_train_offset.reset_index(inplace = True)
df_test_offset.reset_index(inplace = True)
df_val_offset.reset_index(inplace = True)

# %%
df_train_offset.columns
# Out:
# Index(['index', 'id', 'offset', 'length', 'specie_ind'], dtype='object')

# %%
df_train_offset.drop('index',axis =1,inplace = True)
df_val_offset.drop('index',axis =1,inplace = True)
df_test_offset.drop('index',axis =1,inplace = True)

# %%
df_train_offset.to_csv("train_offset.csv")

# %% [markdown]
# ### Let's check for data leakage in offsets

# %%
pd.merge(df_train_offset , df_test_offset , on = 'id', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [id, offset_x, length_x, specie_ind_x, offset_y, length_y, specie_ind_y]
# Index: []

# %%
pd.merge(df_train_offset , df_val_offset , on = 'id', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [id, offset_x, length_x, specie_ind_x, offset_y, length_y, specie_ind_y]
# Index: []

# %%
pd.merge(df_test_offset , df_val_offset , on = 'id', how = 'inner')
# Out:
# Empty DataFrame
# Columns: [id, offset_x, length_x, specie_ind_x, offset_y, length_y, specie_ind_y]
# Index: []

# %% [markdown]
# ### At this stage we've a dataframe of recordin ids and each row corresponds to a 1.92 secs recording or shorter

# %%
specie_dist = []
def get_specie_distri(df , classes , type_df = None):
    """This function takes a dataframe and provides a count of each specie class"""
    for i in range(len(classes)):
        print("DF type = " + str(type_df))
        df_temp = df[df['specie_ind'] == i]
        print("i = " +str(i))
        print(len(df_temp))
        if type_df == "train" :
            specie_dist.append(len(df_temp))

# %%
get_specie_distri(df_train_offset , classes , type_df = "train")
# Out:
# DF type = train
# i = 0
# 12477
# DF type = train
# i = 1
# 7118
# DF type = train
# i = 2
# 1116
# DF type = train
# i = 3
# 6523
# DF type = train
# i = 4
# 2027
# DF type = train
# i = 5
# 950
# DF type = train
# i = 6
# 1305
# DF type = train
# i = 7
# 723

# %%
np.array(df_train_offset.specie_ind)
from sklearn.utils import class_weight
specie_dist = class_weight.compute_class_weight('balanced',classes=np.unique(np.array(df_train_offset.specie_ind)),y=np.array(np.array(df_train_offset.specie_ind)))
#print(class_weights)


specie_dist_ar = np.array(specie_dist)
print(specie_dist_ar)
sum_all = np.sum(specie_dist_ar)
print("sum_all = " +str(sum_all))
specie_dist_pr = specie_dist_ar/sum_all
print("specie_dist_pr = " +str(specie_dist_pr))
sum_pr = np.sum(specie_dist_pr)
print(sum_pr)
# Out:
# [0.32298429 0.56615271 3.6109991  0.61779473 1.98809817 4.24197368
#  3.08802682 5.57382434]
# sum_all = 20.00985385461841
# specie_dist_pr = [0.01614126 0.0282937  0.18046104 0.03087452 0.09935596 0.21199424
#  0.15432531 0.27855398]
# 1.0

# %%
#np.array(df_val_offset.specie_ind)
from sklearn.utils import class_weight
specie_dist_val = class_weight.compute_class_weight('balanced',classes=np.unique(np.array(df_train_offset.specie_ind)),y=np.array(np.array(df_train_offset.specie_ind)))
#print(class_weights)


specie_dist_ar = np.array(specie_dist)
print(specie_dist_ar)
sum_all = np.sum(specie_dist_ar)
print("sum_all = " +str(sum_all))
specie_dist_pr = specie_dist_ar/sum_all
print("specie_dist_pr = " +str(specie_dist_pr))
sum_pr = np.sum(specie_dist_pr)
print(sum_pr)
# Out:
# [0.32298429 0.56615271 3.6109991  0.61779473 1.98809817 4.24197368
#  3.08802682 5.57382434]
# sum_all = 20.00985385461841
# specie_dist_pr = [0.01614126 0.0282937  0.18046104 0.03087452 0.09935596 0.21199424
#  0.15432531 0.27855398]
# 1.0

# %%
get_specie_distri(df_val_offset , classes , type_df = "Val")
# Out:
# DF type = Val
# i = 0
# 3613
# DF type = Val
# i = 1
# 1994
# DF type = Val
# i = 2
# 230
# DF type = Val
# i = 3
# 1855
# DF type = Val
# i = 4
# 280
# DF type = Val
# i = 5
# 228
# DF type = Val
# i = 6
# 426
# DF type = Val
# i = 7
# 66

# %%
get_specie_distri(df_test_offset , classes , type_df = "test")
# Out:
# DF type = test
# i = 0
# 4356
# DF type = test
# i = 1
# 1879
# DF type = test
# i = 2
# 439
# DF type = test
# i = 3
# 1959
# DF type = test
# i = 4
# 507
# DF type = test
# i = 5
# 312
# DF type = test
# i = 6
# 441
# DF type = test
# i = 7
# 194

# %%
def test_model_siamese(model, loader,criterion, classes = classes,device=None , call = "val", DEBUG = DEBUG):
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    with torch.no_grad():
        model.eval()
        test_loss = 0.0
        all_y_pred = []
        all_y = []
        all_y_pred_dict = {}
        count = 0
        print("&&&&&&& INSIDE TEST&&&&&&&" + "for call = " + str(call))
        for ind, (mainImg, imgSets, label) in enumerate(loader):
            mainImg = mainImg.to(device)
            #print("mainImg shape = " +str(mainImg.shape))
            predVal = 0
            pred = -1
            label = label.to(device)
            label_cpu = label.cpu().detach()
            all_y.append(label_cpu)
            #print("all_y = " +str(all_y))
            y_hat_list = []
            for i , testImg in enumerate(imgSets):
                #print("i = " +str(i))
                testImg = testImg.to(device)
                output = model(mainImg, testImg)
                #output_cpu = output.cpu().detach()
                #print("output = \n" + str(output) )
                y_hat_list.append(output.cpu().detach())
                #pred = output_cpu.index(max(output_cpu))
                loss = criterion(output.to(device) , label.to(device))
                test_loss+= loss.item()
                #print("output_list = " +str(output_list))
                del output
            ## finished checking against all the 
            del label
            #print("y_hat_list = " +str(y_hat_list))
            pred = y_hat_list.index(max(y_hat_list))
            #print("pred = " +str(pred))
            #print("prediction  for index  " + str(ind) + "=> " + str(pred))
            all_y_pred.append(pred)
            
        all_y = torch.cat(all_y)
        all_y_pred = np.array(all_y_pred)
        test_loss = test_loss/len(test_loader)  
        test_acc = accuracy_score(all_y.numpy(), all_y_pred)
        #print("before returning , all_y = " +str(all_y.numpy()))
        #print("before returning , all_y_pred  = " +str(all_y_pred))
    
    return test_loss, test_acc , all_y,all_y_pred

# %%
def train_siamese(model, train_loader, val_loader,test_loader , classes , num_epochs = num_epochs , DEBUG = DEBUG):
    #loss_scaler = NativeScaler()
    torch.manual_seed(0)
    global_step = 0
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    print(f'Training on {device}')    
    model = model.to(device)
    criterion = BinaryCrossEntropy(smoothing=0.1)
    optimiser = timm.optim.create_optimizer_v2(model.parameters(), lr=config_pytorch.lr/10,opt = 'lookahead_adam')
    #optimiser = timm.optim.AdamW(model.parameters(), lr=config_pytorch.lr)
    timm.optim.Lookahead(optimiser, alpha=0.5, k=6)
    num_epochs = num_epochs
    all_train_loss = []
    all_train_acc = []
    all_val_acc = []
    all_val_acc = []
    best_val_loss = np.inf
    best_val_acc = -np.inf
    best_train_loss = np.inf
    best_train_acc = -np.inf
    best_epoch = -1
    checkpoint_name = None
    overrun_counter = 0
    lr_log = []
    sigmoid = nn.Sigmoid()
        
    for e in range(num_epochs):
        train_running_loss = 0.0 
        model.train()
        all_y_pred = []
        all_y  = []
        start_time = time.time()
        for ind , (img1, img2, y) in enumerate(train_loader):
            #print("ind inside train loop = " + str(ind))
            x1 = img1.to(device)
            x2 = img2.to(device)
            y = y.to(device)
            
            #print("img1 shape = " +str(img1.shape))
            #print("img2 shape = " +str(img2.shape))
            
            if ind % 600 == 0 :
                elapsed_time = time.time()
                time_since_epoch = (elapsed_time - start_time)/60
                print("epoch = "+ str(e) + "processed batch " + str(ind) + " of " + str(len(train_loader)))
                print("duration = " + str(time_since_epoch))
            # AMP                
            with autocast():
                y_pred = model(x1,x2)
                #print("y_pred Raw = " + str(y_pred))
                loss = criterion(y_pred, y)
                #print("loss = " +str(loss))   
            train_running_loss += loss.item()
            #print("train_running_loss = " +str(train_running_loss))   
            avg_train_loss = train_running_loss / len(train_loader)
            all_y.append(y.cpu().detach())
            #print("y = " +str(y))
            y_pred_prob = sigmoid(y_pred)
            #print("y_pred_prob = " +str(y_pred_prob))
            y_pred_bool = (y_pred_prob > .5).int()
            #print("y_pred_bool = " +str(y_pred_bool))
            
            
            y_pred_cpu = y_pred_bool.cpu().detach()
            if DEBUG:
                print("y_pred_bool = " + str(y_pred_cpu))
            all_y_pred.append(y_pred_cpu.cpu().detach())
            #print("all_y_pred = " +str(all_y_pred))
            optimiser.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(),error_if_nonfinite=True ,max_norm = 5.0 )
            optimiser.step()
            del x1
            del x2
            del y
        

        optimiser.sync_lookahead()
        lr_log.append(lr)
        all_train_loss.append(train_running_loss/len(train_loader))
        all_y = torch.cat(all_y)
        all_y_pred = torch.cat(all_y_pred)
        #print("********BATCH PROCESS FINISH*********")
        #print("all_y = " +str(all_y))
        #print("all_y_pred = " +str(all_y_pred))
        
        train_acc = accuracy_score(all_y.numpy(), all_y_pred.numpy()) 
        all_train_acc.append(train_acc)
        #val_loss, val_f1 , _,_ = test_model_siamese(model, val_loader, criterion = criterion, classes = classes ,device=device, call = "val")
        val_loss, val_acc , _,_ = test_model_siamese(model, val_loader, criterion = criterion, classes = classes ,device=device, call = "val")
        all_val_acc.append(val_acc)
        
        #val_loss = test_model_siamese(model, val_loader, criterion, 0.5, device=device)
        acc_metric = val_acc
        best_acc_metric = best_val_acc
        #check if the current val_loss is less than the best -val loss
        if acc_metric > best_acc_metric:  
            overrun_counter = -1
            checkpoint_name = f'model_e{e}_{datetime.now().strftime("%Y_%m_%d_%H_%M_%S")}.pth'
            torch.save(model.state_dict(), os.path.join(config.model_dir,  checkpoint_name))
            sys.stdout.flush()
            print('Epoch: %d, Train Loss: %.8f, Train acc: %.8f, Val Loss: %.8f, Val acc: %.8f, overrun_counter %i' % (e, train_running_loss, train_acc, val_loss, val_acc,  overrun_counter))
            print('Saving model to:', os.path.join(config.model_dir,  checkpoint_name)) 
            print("Now printing classification report... ")
            print("********************************")
            sys.stdout.flush()
            from sklearn.metrics import classification_report
            #_, _ , all_y_test,all_y_pred_test = test_model_siamese(model, test_loader, criterion = criterion, classes = classes ,device=device, call = "test")
            _, _ , all_y_test,all_y_pred_test = test_model_siamese(model, test_loader, criterion = criterion, classes = classes ,device=device, call = "test")
            
            # at times output is not getting printed. Could be due to multi threading and hence adding sleep
            sys.stdout.flush()
            print(classification_report(all_y_test.numpy(), all_y_pred_test, target_names= classes))
            print("********************************")
            sys.stdout.flush()
            plot_confusion_matrix(all_y_test.numpy() ,all_y_pred_test, classes)
            best_epoch = e
            best_val_acc = val_acc
            best_val_loss = val_loss
            
            
        else:
            print("..Overrun....no improvement")
            overrun_counter += 1
            sys.stdout.flush()
            print('Epoch: %d, Train Loss: %.8f, Train acc: %.8f, Val Loss: %.8f, Val acc: %.8f, overrun_counter %i' % (e, train_running_loss, train_acc, val_loss, val_acc,  overrun_counter))
        if overrun_counter > config_pytorch.max_overrun:
            break
            
    
    return model, lr_log

# %%
def plot_confusion_matrix(y_true,y_hat,classes):
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(y_true,y_hat,labels= range(len(classes)))
    import seaborn as sns
    ax= plt.subplot()
    sns.heatmap(cm, annot=True, ax = ax, fmt = 'g'); #annot=True to annotate cellsplt.xticks(rotation=90)
    ax.xaxis.set_ticklabels(classes, fontsize = 10)
    ax.xaxis.tick_bottom()
    plt.xticks(rotation=90)
    ax.set_ylabel('True', fontsize=20)
    ax.yaxis.set_ticklabels(classes, fontsize = 10)
    plt.yticks(rotation=0)
    plt.show()

# %%
#check the min length based on config params
min_length = (config.win_size * config.n_hop) / config.rate
min_length
# Out:
# 1.92

# %%
# This function pads a file with 0s to make it a 1.92 sec file
def pad_mean(x_temp,rate = config.rate, min_length = config.min_duration ):
    if DEBUG:
        print("inside padding mean...")
    x_mean = torch.mean(x_temp)
    #x_mean.cuda()
    
    if DEBUG:
        print("X_mean = " + str(x_mean))
    left_pad_amt = int((rate*min_length-x_temp.shape[1])//2)
    if DEBUG:
        print("left_pad_amt = " + str(left_pad_amt))
    left_pad = torch.zeros(1,left_pad_amt) #+ (0.1**0.5)*torch.randn(1, left_pad_amt)
    if DEBUG:
        print("left_pad shape = " + str(left_pad.shape))
    left_pad_mean_add = left_pad + x_mean
    if DEBUG:
        print("left_pad_mean shape = " + str(left_pad_mean_add))
        print("sum of left pad mean add = " + str(torch.sum(left_pad_mean_add)))
    
    right_pad_amt = int(rate*min_length-x_temp.shape[1]-left_pad_amt)
    right_pad = torch.zeros(1,right_pad_amt)# + (0.1**0.5)*torch.randn(1, right_pad_amt)
    if DEBUG:
        print("right_pad shape = " + str(right_pad.shape))
    right_pad_mean_add = right_pad + x_mean
    if DEBUG:
        print("right_pad_mean shape = " + str(right_pad_mean_add))
        print("sum of right pad mean add = "  + str(torch.sum(right_pad_mean_add)))
    
    
    
    f = torch.cat([left_pad,x_temp,right_pad],dim=1)[0]
    f = f.unsqueeze(dim = 0)
    #print("returning a tensor of shape = " + str(f.shape))
    return(f)

# %%
def pcen(x, eps=1e-6, s=0.025, alpha=0.98, delta=2, r=0.5, training=False):
    frames = x.split(1, -2)
    m_frames = []
    last_state = None
    for frame in frames:
        if last_state is None:
            last_state = s * frame
            m_frames.append(last_state)
            continue
        if training:
            m_frame = ((1 - s) * last_state).add_(s * frame)
        else:
            m_frame = (1 - s) * last_state + s * frame
        last_state = m_frame
        m_frames.append(m_frame)
    M = torch.cat(m_frames, 1)
    if training:
        pcen_ = (x / (M + eps).pow(alpha) + delta).pow(r) - delta ** r
    else:
        pcen_ = x.div_(M.add_(eps).pow_(alpha)).add_(delta).pow_(r).sub_(delta ** r)
    return pcen_


class PCENTransform(nn.Module):

    def __init__(self, eps=1e-6, s=0.025, alpha=0.98, delta=2, r=0.5, trainable=True):
        super().__init__()
        if trainable:
            self.log_s = nn.Parameter(torch.log(torch.Tensor([s])))
            self.log_alpha = nn.Parameter(torch.log(torch.Tensor([alpha])))
            self.log_delta = nn.Parameter(torch.log(torch.Tensor([delta])))
            self.log_r = nn.Parameter(torch.log(torch.Tensor([r])))
        else:
            self.s = s
            self.alpha = alpha
            self.delta = delta
            self.r = r
        self.eps = eps
        self.trainable = trainable

    def forward(self, x):
#         x = x.permute((0,2,1)).squeeze(dim=1)
        if self.trainable:
            x = pcen(x, self.eps, torch.exp(self.log_s), torch.exp(self.log_alpha), torch.exp(self.log_delta), torch.exp(self.log_r), self.training and self.trainable)
        else:
            x = pcen(x, self.eps, self.s, self.alpha, self.delta, self.r, self.training and self.trainable)
#         x = x.unsqueeze(dim=1).permute((0,1,3,2))
        return x

# %%
def apply_aug(x,rate):
        apply_augmentation = Compose(transforms=[AddColoredNoise(p = .50) ,TimeInversion( p = .50) ,PolarityInversion(p = .50)])
        aug_audio = apply_augmentation(x,sample_rate = rate)
        return(aug_audio)
    

class augment_audio(nn.Module):
    """This is a class to introduce randomness in the data.
    We implement it as a layer in the NN to ensure that it learns from the propertis of the data"""
    def __init__(self , trainable = True, sample_rate = config.rate):
        super().__init__()
        self.trainable = trainable
        self.rate = sample_rate
            
    def forward(self, x):
        x = x.unsqueeze(dim = 1)
           
        if self.trainable:
            x = apply_aug(x , self.rate)
        else:
            x = x
#         x = x.unsqueeze(dim=1).permute((0,1,3,2))
        return x.squeeze(dim = 1)

# %%
class Normalization():
    """This class is for normalizing the spectrograms batch by batch. The normalization used is min-max, two modes 'framewise' and 'imagewise' can be selected. In this paper, we found that 'imagewise' normalization works better than 'framewise'"""
    def __init__(self, mode='framewise'):
        if mode == 'framewise':
            def normalize(x):
                size = x.shape
                x_max = x.max(1, keepdim=True)[0] # Finding max values for each frame
                x_min = x.min(1, keepdim=True)[0]  
                output = (x-x_min)/(x_max-x_min) # If there is a column with all zero, nan will occur
                output[torch.isnan(output)]=0 # Making nan to 0
                return output
        elif mode == 'imagewise':
            def normalize(x):
                size = x.shape
                x_max = x.reshape(size[0], size[1]*size[2]).max(1, keepdim=True)[0]
                x_min = x.reshape(size[0], size[1]*size[2]).min(1, keepdim=True)[0]
                x_max = x_max.unsqueeze(1) # Make it broadcastable
                x_min = x_min.unsqueeze(1) # Make it broadcastable 
                return (x-x_min)/(x_max-x_min)
        else:
            print(f'please choose the correct mode')
        self.normalize = normalize

    def __call__(self, x):
        return self.normalize(x)

# %%
class Moz_train_dataset(Dataset):
    def __init__(self, audio_df, setSize , data_dir, min_length, cache=None, transform=None,rate = config.rate, DEBUG = DEBUG,p = specie_dist_pr):
        """
        Args:
            audio_df (DataFrame): from get_offsets_df function 
            data_dir (string): Directory with all the wavs.
            cache (dict): Empty dictionary used as cache
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.audio_df = audio_df
        self.data_dir = data_dir
        self.min_length = min_length
        self.transform = transform
        self.cache = cache
        self.setSize = setSize
        self.p = p
        

    def __len__(self):
        return self.setSize
    
    def _get_tensor_(self, path, resample=None):
        waveform, inp_samp_rate = torchaudio.load(path)
        
        if inp_samp_rate != config.rate:
            import torchaudio.transforms as T
            resampler = T.Resample(inp_samp_rate, config.rate, dtype=waveform.dtype)
            waveform = resampler(waveform)
        
        if waveform.shape[1] < config.rate*config.min_duration :
            waveform = pad_mean(waveform)
            if DEBUG:
                print("need to pad")
            #waveform = waveform.unsqueeze(dim = 0)
        
        f = waveform[0]
        f_out = f.unsqueeze(0)
        
        return f_out, config.rate

    def __getitem__(self, idx):
        all_uniq_ind = self.audio_df.specie_ind.unique()
        #print("idx in __get__item = " + str(idx))
        if idx % 2 == 0:
            # select the same character for both images
            category = int(np.random.choice(a= all_uniq_ind, size= 1, replace=False))
            #select two images belonging to the category chosen.
            df_temp = self.audio_df[self.audio_df['specie_ind']== category].sample(2,replace = False )
            df_temp.reset_index(inplace = True)
            if DEBUG:
                print("df_temp = " + str(df_temp))
            row1 = df_temp.iloc[0]
            row2 = df_temp.iloc[1]
            if DEBUG:
                print("row1.id = " + str(row1.id))
                print("row2.id = " + str(row2.id))
            label = 1.0
            # x_full  and x2_full represnts the entire tensor representations of the wav file
            x1_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{int(row1.id)}.wav"), resample=config.rate)
            x2_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{int(row2.id)}.wav"), resample=config.rate)
            if DEBUG:
                print("x1_full shape = " + str(x1_full.shape))
                print("x2_full shape = " + str(x2_full.shape))
                        
            r1_offset = int(row1.offset)
            r2_offset = int(row2.offset)
            if DEBUG:
                print("self.min_length = " +str(self.min_length))
                print("even ind row1_offset = " + str(r1_offset))
                print("even ind row2_offset = " + str(r2_offset))
                print("row1_offset type = " + str(type(r1_offset)))
                print("row2_offset type = " + str(type(r2_offset)))
            
            x1 = x1_full[:,r1_offset:int(r1_offset+config.rate*self.min_length)]
            x2 = x2_full[:,r2_offset:int(r2_offset+config.rate*self.min_length)]
            if DEBUG:
                print("x1 shape = " + str(x1.shape))
                print("x2 shape = " + str(x2.shape))
            
        else:
            if DEBUG:
                print("^^^^^^^^ODD INDEX^^^^^^^^^^")
            category1, category2 = np.random.choice(a= all_uniq_ind, size= 2, replace=False)
            df_temp_cat1 = self.audio_df[self.audio_df['specie_ind']== int(category1)].sample(1,replace = False )
            df_temp_cat2 = self.audio_df[self.audio_df['specie_ind']== int(category2)].sample(1,replace = False )
            df_temp_cat1.reset_index(inplace = True)
            df_temp_cat2.reset_index(inplace = True)
            label = 0.0
            
            row1 = df_temp_cat1.iloc[0]
            row2 = df_temp_cat2.iloc[0]
            if DEBUG:
                print("row1.id = " + str(row1.id))
                print("row2.id = " + str(row2.id))
            
            # x_full  and x2_full represnts the entire tensor representations of the wav file
            x1_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{int(row1.id)}.wav"), resample=config.rate)
            x2_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{int(row2.id)}.wav"), resample=config.rate)
            if DEBUG:
                print("x1_full shape = " + str(x1_full.shape))
                print("x2_full shape = " + str(x2_full.shape))
            
            r1_offset = int(row1.offset)
            r2_offset = int(row2.offset)
            if DEBUG:
                print("self.min_length = " +str(self.min_length))
                print("row1_offset = " + str(r1_offset))
                print()
                print("row1_offset type = " + str(type(r1_offset)))
                print("row2_offset = " + str(r2_offset))
                print("row2_offset type = " + str(type(r2_offset)))
            
            x1 = x1_full[:,r1_offset:int(r1_offset+config.rate*self.min_length)]
            x2 = x2_full[:,r2_offset:int(r2_offset+config.rate*self.min_length)]
            if DEBUG:
                print("x1 shape = " + str(x1.shape))
                print("x2 shape = " + str(x2.shape))
            
            
                                   
        
        return (x1,x2,torch.from_numpy(np.array([label], dtype=np.float32)))

# %%
class Moz_test_dataset(Dataset):
    
    def __init__(self, audio_df, setSize , data_dir, min_length, cache=None, transform=None,rate = config.rate,numway = len(classes)):
        """
        Args:
            audio_df (DataFrame): from get_offsets_df function 
            data_dir (string): Directory with all the wavs.
            cache (dict): Empty dictionary used as cache
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.audio_df = audio_df
        self.data_dir = data_dir
        self.min_length = min_length
        self.transform = transform
        self.cache = cache
        self.setSize = setSize
        self.numway = numway

    def __len__(self):
        return self.setSize
    
    def _get_tensor_(self, path, resample=None):
        waveform, inp_samp_rate = torchaudio.load(path)
        
        if inp_samp_rate != config.rate:
            import torchaudio.transforms as T
            resampler = T.Resample(inp_samp_rate, config.rate, dtype=waveform.dtype)
            waveform = resampler(waveform)
        
        if waveform.shape[1] < config.rate*config.min_duration :
            if DEBUG:
                print("inside MozTest Dataset..")
                print("need to pad")
            waveform = pad_mean(waveform)
            #waveform = waveform.unsqueeze(dim = 0)
        
        f = waveform[0]
        f_out = f.unsqueeze(0)
        
        return f_out, config.rate

    def __getitem__(self, idx):
        all_uniq_ind = self.audio_df.specie_ind.unique()
        # find one main image
        all_uniq_ind = df.specie_ind.unique()
        category =  int(np.random.choice(a= all_uniq_ind, size= 1, replace=False))
        #sample a random value from the category chosen above
        df_main = self.audio_df[self.audio_df['specie_ind']== category].sample(1,replace = False )
        df_main.reset_index(inplace = True)
        if DEBUG:
            print("df_main = " + str(df_main))
                 
        # find n numbers of distinct images, 1 in the same set as the main
        testSet = []
        label = int(np.random.choice(a= all_uniq_ind, size= 1, replace=False))
        if DEBUG:
            print("label ->" +str(label))
            print("self.numway = " +str(self.numway))
        for i in range(self.numway):
            #print("i = " +str(i))
            if i == label:
                #estImgName = random.choice(os.listdir(imgDir))
                df_name = "df_temp_" + str(label)
                df_temp = self.audio_df[self.audio_df['specie_ind']== label].sample(1,replace = False )
                #print("i == label")
                #print("df_temp = " +str(df_temp))
                            
            else:
                df_name = "df_temp_" + str(i)
                testCategory = int(np.random.choice(a= all_uniq_ind, size= 1, replace=False))
                df_temp = self.audio_df[self.audio_df['specie_ind']== testCategory].sample(1,replace = False )
                
                

            testSet.append(df_temp)
        df_test = pd.concat(testSet, ignore_index=True)
        if DEBUG:
            print("df_test = " +str(df_test))
            #you loophere on the dataframe to get x's 
            
                
        # x_full  and x2_full represnts the entire tensor representations of the wav file
        #x1_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{row1.id}.wav"), resample=config.rate)
        main_row = df_main.iloc[0]
        #print(main_row)
        x_main_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{int(main_row.id)}.wav"), resample=config.rate)
        #print("x_main_full shape = " + str(x_main_full.shape))
        
        main_offset = int(main_row.offset)
        #print("main_offset  = " + str(main_offset))
        
        x_main = x_main_full[:,main_offset:int(main_offset+config.rate*self.min_length)]
        #print("x_main shape = " + str(x_main.shape))
        
        x_test = []
        for ind,row in df_test.iterrows():
            row_id = row['id']
            #print("inside loop.... row_id = " + str(row_id))
            x_full, _ = self._get_tensor_(os.path.join(self.data_dir,f"{int(row_id)}.wav"), resample=config.rate)
            #print("inside loop.... x_full = " + str(x_full.shape))
            offset = int(row['offset'])
            #print("inside loop...offset  = " + str(offset))
            x_temp = x_full[:,offset:int(offset+config.rate*self.min_length)]
            #print("inside loop...x_temp shape   = " + str(x_temp.shape))
            
            x_test.append(x_temp)
        
        return x_main,x_test,torch.from_numpy(np.array([label], dtype=np.float32))

# %%
class Model(nn.Module):
    def __init__(self, model_name, image_size,threshold = .5):
        super().__init__()
        # num_classes=0 removes the pretrained head
        self.backbone = timm.create_model(model_name,
                        pretrained=True,  in_chans=1, 
                        drop_path_rate=0.2, global_pool='max',
                        drop_rate=0.2)
        
        self.spec_layer = features.STFT(n_fft=int(config.NFFT), freq_bins=None, hop_length=int(config.n_hop),
                              window='hann', freq_scale='linear', center=True, pad_mode='reflect',
                           sr=config.rate, output_format="Magnitude", trainable=True,)
        self.out = nn.Linear(self.backbone.num_features, 1)
        self.sizer = VT.Resize((image_size,image_size))
        self.timeMasking = T.TimeMasking(time_mask_param=int(config.win_size*0.4), iid_masks=True)
        self.freqMasking = T.FrequencyMasking(freq_mask_param=int((config.NFFT//4)*0.15), iid_masks=True)
        self.norm_layer = Normalization(mode='framewise')
        self.pcen_layer = PCENTransform(eps=1e-6, s=0.025, alpha=0.6, delta=0.1, r=0.2, trainable=True)
        #self.augment_layer = augment_audio(trainable = True, sample_rate = config.rate)
        #1000 due to the size of the final layer in convnext
        self.fcOut = nn.Linear(1000, 1)
        self.sigmoid  = nn.Sigmoid()
        self.threshold  = threshold
        
        
    def forward(self, x1,x2):
        # first compute spectrogram
        #spec1 = self.augment_layer(x1.squeeze())
        spec1 = self.spec_layer(x1)  # (B, F, T)
        # normalize
#         spec = spec.transpose(1,2) # (B, T, F)
        spec1 = self.pcen_layer(spec1)
        spec1 = self.norm_layer(spec1)
        
#         if self.training:
#             spec = self.timeMasking(spec)
#             spec = self.freqMasking(spec)

        # then size for CNN model
        # and create a channel
        spec1 = self.sizer(spec1)
        #print("spec1 shape post STFT = " +str(spec1.shape))
        x1 = spec1.unsqueeze(1)
        #print("post unsqueeze x1 shape = " +str(x1.shape))
        # then repeat channels
        x1 = self.backbone(x1)
        x1 = self.sigmoid(x1)
        #print("post backbone . x1 shape = " +str(x1.shape))
        
        #spec2 = self.augment_layer(x2.squeeze())
        spec2 = self.spec_layer(x2)  # (B, F, T)
        # normalize
#         spec = spec.transpose(1,2) # (B, T, F)
        spec2 = self.pcen_layer(spec2)
        spec2 = self.norm_layer(spec2)
        
#         if self.training:
#             spec = self.timeMasking(spec)
#             spec = self.freqMasking(spec)

        # then size for CNN model
        # and create a channel
        spec2 = self.sizer(spec2)
        #print("spec2 shape post STFT = " +str(spec2.shape))
        x2 = spec2.unsqueeze(1)
        #print("post unsqueeze x2 shape = " +str(x2.shape))
        # then repeat channels
        x2 = self.backbone(x2)
        #print("post backbone . x2 shape = " +str(x2.shape))
        x2 = self.sigmoid(x2)      
        x = torch.abs(x1-x2)
        #print(" x shape = " +str(x.shape))
        out = self.fcOut(x)
        #out = F.relu(x)
        #print("output of fcout = " +str(x))
        #print("output = " +str(out))
        return out

# %%
USE_SHORT_AUDIO = True
pin_memory=True
#train_size = 100
test_batch_size = 1
DEBUG = False
num_workers_test = 4
num_workers_train =8
pin_memory=True
#train_size = 100
batch_size = 64

if DEBUG:
    train_size = 20
else:
    train_size = 100000

train_dataset = Moz_train_dataset(audio_df = df_train_offset,data_dir = config.data_dir, setSize = train_size, min_length = config.min_duration, p = specie_dist_pr)
val_dataset = Moz_test_dataset(audio_df = df_val_offset,data_dir = config.data_dir, setSize = 560, min_length = config.min_duration, numway = len(classes))
test_dataset = Moz_test_dataset(audio_df = df_test_offset, setSize = 560,  data_dir = config.data_dir, min_length= config.min_duration, numway = len(classes))

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, num_workers= num_workers_train, pin_memory=True, shuffle = True)
val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=test_batch_size, num_workers= num_workers_test, pin_memory=False , shuffle = False )
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=test_batch_size, num_workers= num_workers_test, pin_memory=False , shuffle = False )

# %% [markdown]
# ## Training

# %%
def load_model(filepath, model):
    # Instantiate model to inspect
    device = torch.device('cuda:0' if torch.cuda.is_available() else torch.device("cpu"))
    print(f'Training on {device}')
        
    if torch.cuda.device_count() > 1:
        print("Using data parallel")
        model = nn.DataParallel(model, device_ids=list(range(torch.cuda.device_count())))
    model = model.to(device)
    # Load trained parameters from checkpoint (may need to download from S3 first)


    if torch.cuda.is_available():
        map_location=lambda storage, loc: storage.cuda()
    else:
        map_location='cpu'
        
    checkpoint = model.load_state_dict(torch.load(filepath))

    return model

# %%
len(val_dataset)
# Out:
# 560

# %%
# Test whether model returns the right values
m_t = Model('convnext_small',224)
x1 = torch.rand(4,1,15360)
x2 = torch.rand(4,1,15360)
x3 = torch.tensor(1)
m_t(x1,x2)
# Out:
# sampling rate = 8000. Please make sure the sampling rate is correct in order toget a valid freq range
# STFT kernels created, time used = 0.0820 seconds
# tensor([[-0.0813],
#         [-0.0866],
#         [-0.1198],
#         [-0.0346]], grad_fn=<AddmmBackward0>)

# %%
model =Model('convnext_small',224)
model, lr_log = train_siamese(model , train_loader, val_loader,test_loader,classes,num_epochs = num_epochs  )
# Out:
# sampling rate = 8000. Please make sure the sampling rate is correct in order toget a valid freq range
# STFT kernels created, time used = 0.0849 seconds
# Training on cuda:0
# epoch = 0processed batch 0 of 1563
# duration = 0.11797624826431274
# epoch = 0processed batch 600 of 1563
# duration = 11.030504202842712
# epoch = 0processed batch 1200 of 1563
# duration = 21.870841964085898
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# Epoch: 0, Train Loss: 1084.12872738, Train acc: 0.49907000, Val Loss: 6.15301552, Val acc: 0.12500000, overrun_counter -1
# Saving model to: ../../models/model_e0_2022_10_09_00_37_32.pth
# Now printing classification report...
# ********************************
# &&&&&&& INSIDE TEST&&&&&&&for call = test
#                        precision    recall  f1-score   support
#
#         an arabiensis       0.15      0.11      0.13        80
# culex pipiens complex       0.09      0.11      0.10        55
#            ae aegypti       0.14      0.12      0.13        86
#        an funestus ss       0.09      0.10      0.10        67
#          an squamosus       0.08      0.07      0.08        85
#           an coustani       0.12      0.20      0.15        51
#          ma uniformis       0.02      0.03      0.03        64
#          ma africanus       0.13      0.10      0.11        72
#
#              accuracy                           0.10       560
#             macro avg       0.10      0.10      0.10       560
#          weighted avg       0.11      0.10      0.10       560
#
# ********************************
# epoch = 1processed batch 0 of 1563
# duration = 0.11860376596450806
# epoch = 1processed batch 600 of 1563
# duration = 11.137060769399007
# epoch = 1processed batch 1200 of 1563
# duration = 22.065466292699178
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 1, Train Loss: 1083.96867573, Train acc: 0.49950000, Val Loss: 6.07819096, Val acc: 0.10892857, overrun_counter 0
# epoch = 2processed batch 0 of 1563
# duration = 0.12940088907877603
# epoch = 2processed batch 600 of 1563
# duration = 11.062334946791331
# epoch = 2processed batch 1200 of 1563
# duration = 21.974411189556122
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# Epoch: 2, Train Loss: 1083.82710022, Train acc: 0.49682000, Val Loss: 6.16735977, Val acc: 0.16250000, overrun_counter -1
# Saving model to: ../../models/model_e2_2022_10_09_01_57_33.pth
# Now printing classification report...
# ********************************
# &&&&&&& INSIDE TEST&&&&&&&for call = test
#                        precision    recall  f1-score   support
#
#         an arabiensis       0.15      0.14      0.15        69
# culex pipiens complex       0.16      0.17      0.17        63
#            ae aegypti       0.12      0.08      0.10        73
#        an funestus ss       0.15      0.16      0.16        68
#          an squamosus       0.10      0.08      0.09        76
#           an coustani       0.11      0.13      0.12        63
#          ma uniformis       0.10      0.11      0.11        80
#          ma africanus       0.13      0.15      0.14        68
#
#              accuracy                           0.13       560
#             macro avg       0.13      0.13      0.13       560
#          weighted avg       0.13      0.13      0.13       560
#
# ********************************
# epoch = 3processed batch 0 of 1563
# duration = 0.12105964024861654
# epoch = 3processed batch 600 of 1563
# duration = 11.160330243905385
# epoch = 3processed batch 1200 of 1563
# duration = 22.10519857406616
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 3, Train Loss: 1083.68862426, Train acc: 0.50015000, Val Loss: 6.18752255, Val acc: 0.11250000, overrun_counter 0
# epoch = 4processed batch 0 of 1563
# duration = 0.11460160811742147
# epoch = 4processed batch 600 of 1563
# duration = 11.059939742088318
# epoch = 4processed batch 1200 of 1563
# duration = 21.95732582807541
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 4, Train Loss: 1083.70804644, Train acc: 0.49653000, Val Loss: 6.18292399, Val acc: 0.09821429, overrun_counter 1
# epoch = 5processed batch 0 of 1563
# duration = 0.1298824985822042
# epoch = 5processed batch 600 of 1563
# duration = 11.085010536511739
# epoch = 5processed batch 1200 of 1563
# duration = 21.995880858103433
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 5, Train Loss: 1083.58742726, Train acc: 0.50252000, Val Loss: 6.15226235, Val acc: 0.11785714, overrun_counter 2
# epoch = 6processed batch 0 of 1563
# duration = 0.12260141372680664
# epoch = 6processed batch 600 of 1563
# duration = 11.092612707614899
# epoch = 6processed batch 1200 of 1563
# duration = 21.98911007642746
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 6, Train Loss: 1083.57544094, Train acc: 0.49655000, Val Loss: 6.14076210, Val acc: 0.11964286, overrun_counter 3
# epoch = 7processed batch 0 of 1563
# duration = 0.12400457064310709
# epoch = 7processed batch 600 of 1563
# duration = 11.067268498738606
# epoch = 7processed batch 1200 of 1563
# duration = 21.932865130901337
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 7, Train Loss: 1083.51169449, Train acc: 0.50035000, Val Loss: 6.12141573, Val acc: 0.10892857, overrun_counter 4
# epoch = 8processed batch 0 of 1563
# duration = 0.12107164859771728
# epoch = 8processed batch 600 of 1563
# duration = 11.052994354565937
# epoch = 8processed batch 1200 of 1563
# duration = 21.924699942270916
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 8, Train Loss: 1083.57045162, Train acc: 0.49851000, Val Loss: 6.12545080, Val acc: 0.09107143, overrun_counter 5
# epoch = 9processed batch 0 of 1563
# duration = 0.11236670811971029
# epoch = 9processed batch 600 of 1563
# duration = 11.071376061439514
# epoch = 9processed batch 1200 of 1563
# duration = 21.94573570092519
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 9, Train Loss: 1083.52407080, Train acc: 0.49982000, Val Loss: 6.16540798, Val acc: 0.12857143, overrun_counter 6
# epoch = 10processed batch 0 of 1563
# duration = 0.13147125244140626
# epoch = 10processed batch 600 of 1563
# duration = 11.09424364566803
# epoch = 10processed batch 1200 of 1563
# duration = 21.984709763526915
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 10, Train Loss: 1083.44661629, Train acc: 0.50130000, Val Loss: 6.10735748, Val acc: 0.10892857, overrun_counter 7
# epoch = 11processed batch 0 of 1563
# duration = 0.11905281146367391
# epoch = 11processed batch 600 of 1563
# duration = 11.085823718706767
# epoch = 11processed batch 1200 of 1563
# duration = 21.9932559688886
# &&&&&&& INSIDE TEST&&&&&&&for call = val
# ..Overrun....no improvement
# Epoch: 11, Train Loss: 1083.55369580, Train acc: 0.49889000, Val Loss: 6.12673179, Val acc: 0.12142857, overrun_counter 8
# epoch = 12processed batch 0 of 1563
# duration = 0.12366216977437337

# %%
timm.optim.Ada

# %%
output = torch.tensor([[-0.0742],
        [-0.6300],
        [-0.2383],
        [-0.1598]], device='cuda:0')

# %%
label = torch.tensor(8, device = "cuda")
print(label)
label_cpu = label.cpu().detach()
print(label_cpu)
label_np = label_cpu.numpy()
print(type(label_np))
label_np_item = label_np.item()
print(type(label_np_item))
